# %% [markdown]
# ### Notebook to calculate for LLC for sweeps

# %%
import os 
import pandas as pd
from utils.LLC_calculation import compute_and_save_llc
from training import ExperimentParams

# %%
path = "/home/se24/geom_phase_transitions/results/sweep2/"
for folder in os.listdir(path):
    full_path = os.path.join(path, folder)
    df_params = pd.read_csv(os.path.join(full_path, "params.csv"))
    params_dict = df_params.to_dict(orient="list")
    for key in params_dict:
        params_dict[key] = params_dict[key][0]
    params = ExperimentParams(**params_dict)
    print(f"Computing LLC for sweep in folder: {folder}")
    try:
        df_loss = compute_and_save_llc(params)
    except Exception as e:
        print(f"Error occurred: {e}")
# Out:
# Computing LLC for sweep in folder: p=17_embed=8
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/slt/sampler.py:117: UserWarning: Using passed in nbeta. Make sure callbacks are also initialized with the same nbeta.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:240: UserWarning: You are taking more draws than burn-in steps, your LLC estimates will likely be underestimates. Please check LLC chain convergence.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:244: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:285: UserWarning: If you're setting a nbeta or temperature in optimizer_kwargs, please also make sure to set it in the callbacks.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:52: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# Chain 0: 100%|██████████| 500/500 [00:01<00:00, 383.45it/s]
# Chain 1: 100%|██████████| 500/500 [00:01<00:00, 387.28it/s]
# Chain 2: 100%|██████████| 500/500 [00:01<00:00, 381.43it/s]
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/slt/sampler.py:117: UserWarning: Using passed in nbeta. Make sure callbacks are also initialized with the same nbeta.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:240: UserWarning: You are taking more draws than burn-in steps, your LLC estimates will likely be underestimates. Please check LLC chain convergence.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:244: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:285: UserWarning: If you're setting a nbeta or temperature in optimizer_kwargs, please also make sure to set it in the callbacks.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:52: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# Error occurred: Default process group has not been initialized, please make sure to call init_process_group.
# Computing LLC for sweep in folder: p=19_embed=8
# Chain 0: 100%|██████████| 500/500 [00:01<00:00, 388.78it/s]
# Chain 1: 100%|██████████| 500/500 [00:01<00:00, 390.07it/s]
# Chain 2: 100%|██████████| 500/500 [00:01<00:00, 387.42it/s]
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/slt/sampler.py:117: UserWarning: Using passed in nbeta. Make sure callbacks are also initialized with the same nbeta.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:240: UserWarning: You are taking more draws than burn-in steps, your LLC estimates will likely be underestimates. Please check LLC chain convergence.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:244: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:285: UserWarning: If you're setting a nbeta or temperature in optimizer_kwargs, please also make sure to set it in the callbacks.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:52: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# Error occurred: Default process group has not been initialized, please make sure to call init_process_group.
# Computing LLC for sweep in folder: p=23_embed=8
# Chain 0: 100%|██████████| 500/500 [00:01<00:00, 389.57it/s]
# Chain 1: 100%|██████████| 500/500 [00:01<00:00, 390.00it/s]
# Chain 2: 100%|██████████| 500/500 [00:01<00:00, 387.55it/s]
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/slt/sampler.py:117: UserWarning: Using passed in nbeta. Make sure callbacks are also initialized with the same nbeta.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:240: UserWarning: You are taking more draws than burn-in steps, your LLC estimates will likely be underestimates. Please check LLC chain convergence.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:244: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:285: UserWarning: If you're setting a nbeta or temperature in optimizer_kwargs, please also make sure to set it in the callbacks.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:52: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# Error occurred: Default process group has not been initialized, please make sure to call init_process_group.
# Computing LLC for sweep in folder: p=29_embed=8
# Chain 0: 100%|██████████| 500/500 [00:01<00:00, 384.47it/s]
# Chain 1: 100%|██████████| 500/500 [00:01<00:00, 388.49it/s]
# Chain 2: 100%|██████████| 500/500 [00:01<00:00, 388.92it/s]
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/slt/sampler.py:117: UserWarning: Using passed in nbeta. Make sure callbacks are also initialized with the same nbeta.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:240: UserWarning: You are taking more draws than burn-in steps, your LLC estimates will likely be underestimates. Please check LLC chain convergence.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:244: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:285: UserWarning: If you're setting a nbeta or temperature in optimizer_kwargs, please also make sure to set it in the callbacks.
#   warnings.warn(
# /home/se24/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:52: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# Error occurred: Default process group has not been initialized, please make sure to call init_process_group.
# Computing LLC for sweep in folder: p=13_embed=8
# Chain 0: 100%|██████████| 500/500 [00:01<00:00, 385.95it/s]
# Chain 1:  79%|███████▉  | 396/500 [00:01<00:00, 380.48it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 11
#       9 print(f"Computing LLC for sweep in folder: {folder}")
#      10 try:
# ---> 11     df_loss = compute_and_save_llc(params)
#      12 except Exception as e:
#      13     print(f"Error occurred: {e}")
#
# File /data/se24/geom_phase_transitions/utils/LLC_calculation.py:24, in compute_and_save_llc(params)
#      22     except FileNotFoundError:
#      23         continue
# ---> 24     llcs.append(estimate_learning_coeff_with_summary(
#      25         model=model,
#      26         loader=DataLoader(train_data, batch_size=params.batch_size, shuffle=True),
#      27         evaluate=evaluate_ce,
#      28         sampling_method=SGLD,
#      29         optimizer_kwargs=dict(lr=0.003, nbeta=2.0, localization=5.0),
#      30         num_chains=3,
#      31         num_draws=500,
#      32         device=DEVICE,
#      33         online=False,
#      34     )['llc/mean'])
#      36 df_loss = pd.read_csv(f"./results/{params.exp_name}/loss_data.csv")
#      37 df_loss["llc"] = llcs
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/slt/sampler.py:164, in estimate_learning_coeff_with_summary(model, loader, callbacks, evaluate, sampling_method, optimizer_kwargs, num_draws, num_chains, num_burnin_steps, num_steps_bw_draws, init_loss, grad_accum_steps, cores, seed, device, gpu_idxs, verbose, optimize_over_per_model_param, online, use_amp)
#     154     llc_estimator = LLCEstimator(
#     155         num_chains,
#     156         num_draws,
#    (...)
#     159         init_loss=init_loss,
#     160     )
#     162 callbacks = [llc_estimator, *callbacks]
# --> 164 sample(
#     165     model=model,
#     166     loader=loader,
#     167     evaluate=evaluate,
#     168     sampling_method=sampling_method,
#     169     optimizer_kwargs=optimizer_kwargs,
#     170     num_draws=num_draws,
#     171     num_chains=num_chains,
#     172     num_burnin_steps=num_burnin_steps,
#     173     num_steps_bw_draws=num_steps_bw_draws,
#     174     grad_accum_steps=grad_accum_steps,
#     175     cores=cores,
#     176     seed=seed,
#     177     device=device,
#     178     verbose=verbose,
#     179     callbacks=callbacks,
#     180     optimize_over_per_model_param=optimize_over_per_model_param,
#     181     gpu_idxs=gpu_idxs,
#     182     use_amp=use_amp,
#     183     init_loss=init_loss,
#     184 )
#     186 results = {}
#     188 for callback in callbacks:
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:369, in sample(model, loader, callbacks, evaluate, sampling_method, optimizer_kwargs, num_draws, num_chains, num_burnin_steps, num_steps_bw_draws, init_loss, grad_accum_steps, cores, seed, device, verbose, optimize_over_per_model_param, gpu_idxs, batch_size, use_amp, **kwargs)
#     367 else:
#     368     for i in range(num_chains):
# --> 369         _sample_single_chain(get_args(i, seeds, device, callbacks, shared_kwargs))
#     371 for callback in callbacks:
#     372     if hasattr(callback, "finalize"):
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:147, in _sample_single_chain(kwargs)
#     145 loader = cloudpickle.loads(kwargs["loader"])
#     146 kwargs = {k: v for k, v in kwargs.items() if k not in pickled_args}
# --> 147 return sample_single_chain(**kwargs, evaluate=evaluate, loader=loader)
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/devinterp/backends/default/slt/sampler.py:139, in sample_single_chain(ref_model, loader, evaluate, optimizer_kwargs, num_draws, num_burnin_steps, num_steps_bw_draws, grad_accum_steps, sampling_method, chain, seed, verbose, device, optimize_over_per_model_param, callbacks, use_amp, **kwargs)
#     137 optimizer.zero_grad()
#     138 cumulative_loss = 0
# --> 139 pbar.update(1)
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/tqdm/std.py:1242, in tqdm.update(self, n)
#    1240     self._ema_dn(dn)
#    1241     self._ema_dt(dt)
# -> 1242 self.refresh(lock_args=self.lock_args)
#    1243 if self.dynamic_miniters:
#    1244     # If no `miniters` was specified, adjust automatically to the
#    1245     # maximum iteration rate seen so far between two prints.
#    1246     # e.g.: After running `tqdm.update(5)`, subsequent
#    1247     # calls to `tqdm.update()` will only cause an update after
#    1248     # at least 5 more iterations.
#    1249     if self.maxinterval and dt >= self.maxinterval:
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/tqdm/std.py:1347, in tqdm.refresh(self, nolock, lock_args)
#    1345     else:
#    1346         self._lock.acquire()
# -> 1347 self.display()
#    1348 if not nolock:
#    1349     self._lock.release()
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/tqdm/std.py:1495, in tqdm.display(self, msg, pos)
#    1493 if pos:
#    1494     self.moveto(pos)
# -> 1495 self.sp(self.__str__() if msg is None else msg)
#    1496 if pos:
#    1497     self.moveto(-pos)
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/tqdm/std.py:459, in tqdm.status_printer.<locals>.print_status(s)
#     457 def print_status(s):
#     458     len_s = disp_len(s)
# --> 459     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     460     last_len[0] = len_s
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/tqdm/std.py:453, in tqdm.status_printer.<locals>.fp_write(s)
#     451 def fp_write(s):
#     452     fp.write(str(s))
# --> 453     fp_flush()
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/tqdm/utils.py:196, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     194 def inner(*args, **kwargs):
#     195     try:
# --> 196         return func(*args, **kwargs)
#     197     except OSError as e:
#     198         if e.errno != 5:
#
# File ~/geom_phase_transitions/venv/lib/python3.8/site-packages/ipykernel/iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File /usr/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File /usr/lib/python3.8/threading.py:306, in Condition.wait(self, timeout)
#     304 else:
#     305     if timeout > 0:
# --> 306         gotit = waiter.acquire(True, timeout)
#     307     else:
#     308         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
